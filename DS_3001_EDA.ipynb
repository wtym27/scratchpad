# %% [markdown]
# <a href="https://colab.research.google.com/github/wtym27/scratchpad/blob/main/DS_3001_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/wtym27/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 22 (from 1)
# Receiving objects: 100% (24/24), 25.56 KiB | 8.52 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/data/craigslist_cville_cars.csv')

# %%
df.shape()
# Out:
# (46, 7)

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  price  \
# 0           0                      a sweet sedan avalon xle plus  24000
# 1           1  1998 gmc sierra 1500 sl truck auto rwd <103,00...   6950
# 2           2        gmc sierra 3500hd 6.6 duramax diesel dually  26000
# 3           3                              2007 chrysler sebring   2900
# 4           4                               2012 nissan versa sl   3500
#
#      year                                               link    brand   age
# 0     NaN  https://charlottesville.craigslist.org/cto/d/c...  missing   NaN
# 1  1998.0  https://charlottesville.craigslist.org/cto/d/l...      gmc  27.0
# 2     NaN  https://charlottesville.craigslist.org/cto/d/c...      gmc   NaN
# 3  2007.0  https://charlottesville.craigslist.org/cto/d/c...  missing  18.0
# 4  2012.0  https://charlottesville.craigslist.org/cto/d/c...  missing  13.0

# %%
df['brand'].describe()
# Out:
# count          46
# unique         14
# top       missing
# freq           14
# Name: brand, dtype: object

# %%
df.loc[df['brand'] == 'Honda', :]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, price, year, link, brand, age]
# Index: []

# %%
df.loc[df['brand'] == 'Toyota', :]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, price, year, link, brand, age]
# Index: []

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x, bins=20, kde=True)
plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
x = df['price'].astype(str).str.replace(',','')
x = pd.to_numeric(x, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3009105188.py in <cell line: 0>()
# ----> 1 x = df['price'].astype(str).str.replace(',','')
# ...

# %%
sns.kdeplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
df = pd.read_csv('/content/data/crimebystatecombinedwithunemployment.csv')

# %%
df.columns
# Out:
# Index(['state', 'unemployment', 'year', 'Population', 'violent total',
#        'Murder', 'rape', 'Robbery', 'Aggravated assault', 'property total',
#        'Burglary', 'Larceny theft', 'vehicle theft'],
#       dtype='object')

# %%
df['Murder'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Murder_ln'] = np.log(df['Murder'])

# %%
sns.histplot(df['Murder_ln'])
# Out:
# <Axes: xlabel='Murder_ln', ylabel='Count'>

# %%
df.Murder
# Out:
# 0       15.1
# 1       14.2
# 2       13.3
# 3       13.2
# 4       13.2
#         ...
# 1984     1.4
# 1985     3.2
# 1986     2.4
# 1987     2.9
# 1988     2.7
# Name: Murder, Length: 1989, dtype: float64

# %%
print(df['Murder'].describe())
print('Mean is ' + str(df['Murder'].mean()))
print('Variance is ' + str(df['Murder'].var()))
print('Standard Deviation is ' + str(df['Murder'].std()))
# Out:
# count    1989.000000
# mean        6.651785
# std         6.560408
# min         0.200000
# 25%         3.200000
# 50%         5.400000
# 75%         8.400000
# max        80.600000
# Name: Murder, dtype: float64
# Mean is 6.651784816490698
# Variance is 43.03895682288847
# Standard Deviation is 6.560408281722142

# %%
sns.kdeplot(df['Murder'])
# Out:
# <Axes: xlabel='Murder', ylabel='Density'>

# %%
df = pd.read_csv('/content/data/airbnb_NYC.csv', encoding='latin1')
